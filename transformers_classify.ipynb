# %%
# !git clone https://github.com/ChaosAIVision/Transformers-training-with-pytorch.git
# Out:
# Cloning into 'Transformers-training-with-pytorch'...
# remote: Enumerating objects: 34, done.
# remote: Counting objects: 100% (34/34), done.
# remote: Compressing objects: 100% (29/29), done.
# remote: Total 34 (delta 9), reused 28 (delta 3), pack-reused 0 (from 0)
# Receiving objects: 100% (34/34), 23.84 KiB | 23.84 MiB/s, done.
# Resolving deltas: 100% (9/9), done.

# %%
# %cd Transformers-training-with-pytorch
# !python train.py -d data.yaml -b8 -e 100 -l 1e-3
# Out:
# [Errno 2] No such file or directory: 'Transformers-training-with-pytorch'
# /content/Transformers-training-with-pytorch
# /usr/local/lib/python3.10/dist-packages/torchtext/data/__init__.py:4: UserWarning:
# /!\ IMPORTANT WARNING ABOUT TORCHTEXT STATUS /!\
# Torchtext is deprecated and the last released version will be 0.18 (this one). You can silence this warning by calling the following at the beginnign of your scripts: `import torchtext; torchtext.disable_torchtext_deprecation_warning()`
#   warnings.warn(torchtext._TORCHTEXT_DEPRECATION_MSG)
# /usr/local/lib/python3.10/dist-packages/torchtext/vocab/__init__.py:4: UserWarning:
# /!\ IMPORTANT WARNING ABOUT TORCHTEXT STATUS /!\
# Torchtext is deprecated and the last released version will be 0.18 (this one). You can silence this warning by calling the following at the beginnign of your scripts: `import torchtext; torchtext.disable_torchtext_deprecation_warning()`
#   warnings.warn(torchtext._TORCHTEXT_DEPRECATION_MSG)
# ...
